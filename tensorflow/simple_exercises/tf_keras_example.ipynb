# %% [markdown]
# Keras Example: https://www.tensorflow.org/guide/keras

# %%
# necssary imports

import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

print(tf.VERSION)
print(tf.keras.__version__)
# Out:
# 1.13.0-rc2
# 2.2.4-tf

# %% [markdown]
# keras uses chekpoint format
#
# HDF5
#
#
# # **Multi Layer Perceptron(FCN)**

# %%
model = tf.keras.Sequential()

# adds densely connected layer with 64 units
model.add(layers.Dense(64, activation='relu', input_shape=(32,)))

# add another
model.add(layers.Dense(64, activation='relu'))

model.add(layers.Dense(10, activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# # Some model parameters

# %%
# Create a sigmoid layer:
layers.Dense(64, activation='sigmoid')
# Or:
layers.Dense(64, activation=tf.sigmoid)

# A linear layer with L1 regularization of factor 0.01 applied to the kernel matrix:
layers.Dense(64, kernel_regularizer=tf.keras.regularizers.l1(0.01))

# A linear layer with L2 regularization of factor 0.01 applied to the bias vector:
layers.Dense(64, bias_regularizer=tf.keras.regularizers.l2(0.01))

# A linear layer with a kernel initialized to a random orthogonal matrix:
layers.Dense(64, kernel_initializer='orthogonal')

# A linear layer with a bias vector initialized to 2.0s:
layers.Dense(64, bias_initializer=tf.keras.initializers.constant(2.0))

# %% [markdown]
# # Train the model

# %%
model.compile(optimizer=tf.train.AdamOptimizer(0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# regression
model.compile(optimizer=tf.train.AdamOptimizer(0.001), 
              loss='mse', 
              metrics=['mae'])

# categorical
model.compile(optimizer=tf.train.AdamOptimizer(0.001), 
              loss=tf.keras.losses.categorical_crossentropy, 
              metrics=[tf.keras.metrics.categorical_accuracy])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
data = np.random.random((1000, 32))
labels = np.random.random((1000, 10))

val_data = np.random.random((100, 32))
val_labels = np.random.random((100, 10))

# datasets
dataset = tf.data.Dataset.from_tensor_slices((data, labels))
dataset = dataset.batch(32)
dataset = dataset.repeat()

val_dataset = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
val_dataset = val_dataset.batch(32)
val_dataset = val_dataset.repeat()

# NORMAL RUN
#model.fit(data, labels, epochs=100, batch_size=32, 
#          validation_data=(val_data, val_labels))

# DATASET RUN:
model.fit(dataset, epochs=10, steps_per_epoch=30, validation_data = val_dataset, validation_steps=3)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 30/30 [==============================] - 1s 18ms/step - loss: 11.5977 - categorical_accuracy: 0.0969 - val_loss: 11.2938 - val_categorical_accuracy: 0.0521
# Epoch 2/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.6124 - categorical_accuracy: 0.1079 - val_loss: 11.0478 - val_categorical_accuracy: 0.0882
# Epoch 3/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.6140 - categorical_accuracy: 0.1335 - val_loss: 11.1899 - val_categorical_accuracy: 0.0882
# Epoch 4/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.5893 - categorical_accuracy: 0.1485 - val_loss: 11.3849 - val_categorical_accuracy: 0.0441
# Epoch 5/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.5862 - categorical_accuracy: 0.1528 - val_loss: 11.2892 - val_categorical_accuracy: 0.1042
# Epoch 6/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.5937 - categorical_accuracy: 0.1667 - val_loss: 11.0516 - val_categorical_accuracy: 0.1471
# Epoch 7/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.5688 - categorical_accuracy: 0.1677 - val_loss: 11.1932 - val_categorical_accuracy: 0.1618
# Epoch 8/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.5893 - categorical_accuracy: 0.1720 - val_loss: 11.3917 - val_categorical_accuracy: 0.1029
# Epoch 9/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.6085 - categorical_accuracy: 0.1795 - val_loss: 11.2928 - val_categorical_accuracy: 0.1667
# Epoch 10/10
# 30/30 [==============================] - 0s 2ms/step - loss: 11.5807 - categorical_accuracy: 0.1795 - val_loss: 11.0561 - val_categorical_accuracy: 0.1324

# %% [markdown]
# # EVALUATE

# %%
eval_data = np.random.random((1000, 32))
eval_labels = np.random.random((1000, 10))

eval_dataset = tf.data.Dataset.from_tensor_slices((eval_data, eval_labels))
eval_dataset = eval_dataset.batch(32)
eval_dataset = eval_dataset.repeat()

model.evaluate(eval_data, eval_labels, batch_size=32)
model.evaluate(eval_dataset, steps=30)
# Out:
# 1000/1000 [==============================] - 0s 73us/sample - loss: 11.5632 - categorical_accuracy: 0.1000
# 30/30 [==============================] - 0s 3ms/step - loss: 11.5337 - categorical_accuracy: 0.1021
# [11.533701642354329, 0.10208333]

# %% [markdown]
# # PREDICT

# %%
test_data = np.random.random((1000, 32))
result = model.predict(test_data, batch_size=32)
print("result.shape: "+str(result.shape))
print("result: "+str(result[0]))
# Out:
# result.shape: (1000, 10)
# result: [0.09679848 0.0964955  0.09384116 0.10381035 0.09537564 0.09494994
#  0.10754777 0.10428934 0.10161144 0.10528041]

# %% [markdown]
# # BUILD ADVANCED MODELS

# %%
inputs = tf.keras.Input(shape=(32,)) # placeholdder

x = layers.Dense(64, activation='relu')(inputs)
x = layers.Dense(64, activation='relu')(x)

predictions = layers.Dense(10, activation="softmax")(x)

model = tf.keras.Model(inputs=inputs, outputs=predictions)

data = np.random.random((1000,32))
labels = np.random.random((1000,10))

model.compile(optimizer=tf.train.RMSPropOptimizer(0.001),
             loss=tf.keras.losses.categorical_crossentropy,
             metrics=[tf.keras.metrics.categorical_accuracy])

model.fit(data, labels, batch_size=32,epochs=5)
# Out:
# Epoch 1/5
# 1000/1000 [==============================] - 0s 156us/sample - loss: 11.6815 - categorical_accuracy: 0.1040
# Epoch 2/5
# 1000/1000 [==============================] - 0s 50us/sample - loss: 11.6236 - categorical_accuracy: 0.1030
# Epoch 3/5
# 1000/1000 [==============================] - 0s 49us/sample - loss: 11.6037 - categorical_accuracy: 0.0900
# Epoch 4/5
# 1000/1000 [==============================] - 0s 51us/sample - loss: 11.5913 - categorical_accuracy: 0.0990
# Epoch 5/5
# 1000/1000 [==============================] - 0s 53us/sample - loss: 11.5805 - categorical_accuracy: 0.1190

# %% [markdown]
# # Build a custom model

# %%
class MyModel(tf.keras.Model):
  def __init__(self,num_classes=10):
    super(MyModel, self).__init__("my_model")
    self.num_classes=num_classes
    
    #define layers
    self.dense_1 = layers.Dense(32, activation='relu')
    self.dense_2 = layers.Dense(num_classes, activation='sigmoid')
    
    
  def call(self, inputs):
    #forward_pass
    x = self.dense_1(inputs)
    return self.dense_2(x)
  
  def compute_output_shape(self, input_shape):
    shape = tf.TensorShape(input_shape).as_list()
    shape[-1] = self.num_classes
    return tf.TensorShape(shape)

# %% [markdown]
# custom model is ready for now.
#
# # Instaniate the new model

# %%
model = MyModel(num_classes=10)

#compile first.
model.compile(optimizer=tf.train.AdamOptimizer(0.001),
             loss=tf.keras.losses.categorical_crossentropy,
             metrics=[tf.keras.metrics.categorical_accuracy])


model.fit(data, labels, batch_size=32, epochs=5)
# Out:
# Epoch 1/5
# 1000/1000 [==============================] - 0s 199us/sample - loss: 11.6566 - categorical_accuracy: 0.1090
# Epoch 2/5
# 1000/1000 [==============================] - 0s 70us/sample - loss: 11.5975 - categorical_accuracy: 0.1030
# Epoch 3/5
# 1000/1000 [==============================] - 0s 59us/sample - loss: 11.5921 - categorical_accuracy: 0.1070
# Epoch 4/5
# 1000/1000 [==============================] - 0s 87us/sample - loss: 11.5880 - categorical_accuracy: 0.1010
# Epoch 5/5
# 1000/1000 [==============================] - 0s 68us/sample - loss: 11.5844 - categorical_accuracy: 0.1100

# %% [markdown]
# # Callbacks

# %%
callbacks=[
    # to prevent overfitting use early stopping
    tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss'),
    # write logs
    tf.keras.callbacks.TensorBoard(log_dir='./logs')
]

model.fit(data, labels, batch_size=32, epochs=20, callbacks=callbacks, validation_data=(val_data, val_labels))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/20
# 1000/1000 [==============================] - 0s 58us/sample - loss: 11.4469 - categorical_accuracy: 0.2100 - val_loss: 11.3889 - val_categorical_accuracy: 0.0600
# Epoch 2/20
# 1000/1000 [==============================] - 0s 57us/sample - loss: 11.4462 - categorical_accuracy: 0.2200 - val_loss: 11.3867 - val_categorical_accuracy: 0.0500
# Epoch 3/20
# 1000/1000 [==============================] - 0s 57us/sample - loss: 11.4460 - categorical_accuracy: 0.2150 - val_loss: 11.3840 - val_categorical_accuracy: 0.0600
# Epoch 4/20
# 1000/1000 [==============================] - 0s 55us/sample - loss: 11.4460 - categorical_accuracy: 0.2120 - val_loss: 11.3845 - val_categorical_accuracy: 0.0500
# Epoch 5/20
# 1000/1000 [==============================] - 0s 57us/sample - loss: 11.4454 - categorical_accuracy: 0.2090 - val_loss: 11.3884 - val_categorical_accuracy: 0.0600
# Epoch 6/20
# 1000/1000 [==============================] - 0s 58us/sample - loss: 11.4464 - categorical_accuracy: 0.2150 - val_loss: 11.3874 - val_categorical_accuracy: 0.0500
# Epoch 7/20
# 1000/1000 [==============================] - 0s 71us/sample - loss: 11.4447 - categorical_accuracy: 0.2040 - val_loss: 11.3913 - val_categorical_accuracy: 0.0600
# Epoch 8/20
# 1000/1000 [==============================] - 0s 67us/sample - loss: 11.4452 - categorical_accuracy: 0.2060 - val_loss: 11.3866 - val_categorical_accuracy: 0.0500
